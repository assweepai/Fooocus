# %%
# !pip install numpy==1.26.4 cupy-cuda12x rembg==2.0.57 --force-reinstall!pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/assweepai/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
